# %% [markdown]
# # Inflation Forecasting

# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import tensorflow as tf

# %%
# import data
df = pd.read_csv('./inflasi-indo.csv')
df
# Out:
#      Unnamed: 0        date  inflation-rate
# 0             0  2003-01-01            2.86
# 1             1  2003-02-01            2.56
# 2             2  2003-03-01            2.28
# 3             3  2003-04-01            3.27
# 4             4  2003-05-01            3.08
# ..          ...         ...             ...
# 246         246  2023-07-01            7.15
# 247         247  2023-08-01            7.62
# 248         248  2023-09-01            7.17
# 249         249  2023-10-01            7.60
# 250         250  2023-11-01            8.68
#
# [251 rows x 3 columns]

# %%
# take inflation-rate column to new dataframe
df_inf = df[['inflation-rate']]
# swap column vertically
df_inf = df_inf[::-1].reset_index(drop=True)
df_inf
# Out:
#      inflation-rate
# 0              8.68
# 1              7.60
# 2              7.17
# 3              7.62
# 4              7.15
# ..              ...
# 246            3.08
# 247            3.27
# 248            2.28
# 249            2.56
# 250            2.86
#
# [251 rows x 1 columns]

# %%
# combine 2 variable
df['inflation-rate'] = df_inf
df
# Out:
#      Unnamed: 0        date  inflation-rate
# 0             0  2003-01-01            8.68
# 1             1  2003-02-01            7.60
# 2             2  2003-03-01            7.17
# 3             3  2003-04-01            7.62
# 4             4  2003-05-01            7.15
# ..          ...         ...             ...
# 246         246  2023-07-01            3.08
# 247         247  2023-08-01            3.27
# 248         248  2023-09-01            2.28
# 249         249  2023-10-01            2.56
# 250         250  2023-11-01            2.86
#
# [251 rows x 3 columns]

# %%
def plot_series(x, y, format="-", start=0, end=None,
                title=None, xlabel=None, ylabel=None, legend=None ):
    """
    Visualizes time series data

    Args:
      x (array of int) - contains values for the x-axis
      y (array of int or tuple of arrays) - contains the values for the y-axis
      format (string) - line style when plotting the graph
      start (int) - first time step to plot
      end (int) - last time step to plot
      title (string) - title of the plot
      xlabel (string) - label for the x-axis
      ylabel (string) - label for the y-axis
      legend (list of strings) - legend for the plot
    """

    # Setup dimensions of the graph figure
    plt.figure(figsize=(10, 6))

    # Check if there are more than two series to plot
    if type(y) is tuple:

      # Loop over the y elements
      for y_curr in y:

        # Plot the x and current y values
        plt.plot(x[start:end], y_curr[start:end], format)

    else:
      # Plot the x and y values
      plt.plot(x[start:end], y[start:end], format)

    # Label the x-axis
    plt.xlabel(xlabel)

    # Label the y-axis
    plt.ylabel(ylabel)

    # Set the legend
    if legend:
      plt.legend(legend)

    # Set the title
    plt.title(title)

    # Overlay a grid on the graph
    plt.grid(True)

    # Draw the graph on screen
    plt.show()

# %%
time_step = []
inflation = []

# append data to array
for i in range(len(df)):
    time_step.append(i)
    inflation.append(df['inflation-rate'][i])

time = np.array(time_step)
series = np.array(inflation)
# plt.figure(figsize=(10, 6))
plot_series(time, series)

# %%
# Define the split time
split_time = 225

# Get the train set
time_train = time[:split_time]
x_train = series[:split_time]

# Get the validation set
time_valid = time[split_time:]
x_valid = series[split_time:]

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
  """
  Creates a windowed dataset out of a time series

  Args:
    series (array of int) - contains the time series
    window_size (int) - the size of the window
    batch_size (int) - the size of the batch
    shuffle_buffer (int) - the size of the shuffle buffer

  Returns:
    dataset - a windowed dataset
  """

  # Create a dataset from the series
  dataset = tf.data.Dataset.from_tensor_slices(series)

  # Window the dataset
  dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)

  # Flatten the dataset
  dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))

  # Shuffle the dataset
  dataset = dataset.shuffle(shuffle_buffer)

  # Map the dataset so that it contains the window and the label
  dataset = dataset.map(lambda window: (window[:-1], window[-1]))

  # Batch the dataset
  dataset = dataset.batch(batch_size).prefetch(1)

  return dataset

# %%
# parameters for the windowed dataset
window_size = 30
batch_size = 32
shuffle_buffer_size = 1000

# Create the windowed dataset
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %%
# Build the Model
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=64, kernel_size=3,
                      strides=1,
                      activation="relu",
                      padding='causal',
                      input_shape=[window_size, 1]),
  tf.keras.layers.LSTM(64, return_sequences=True),
  tf.keras.layers.LSTM(64),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 400)
])

 # Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 30, 64)            256
#
#  lstm (LSTM)                 (None, 30, 64)            33024
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 30)                1950
#
#  dense_1 (Dense)             (None, 10)                310
#
#  dense_2 (Dense)             (None, 1)                 11
#
#  lambda (Lambda)             (None, 1)                 0
#
# =================================================================
# Total params: 68,575
# Trainable params: 68,575
# Non-trainable params: 0
# _________________________________________________________________

# %%
init_weight = model.get_weights()
# print(init_weight)

# %%
epochs = 100
# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
# optimizer = tf.keras.optimizers.SGD(momentum=0.9)
optimizer = tf.keras.optimizers.Adam(lr=1e-8)
# optimizer = tf.keras.optimizers.RMSprop(lr=1e-8, rho=0.9, epsilon=1e-08, decay=0.0)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model.fit(train_set, epochs=epochs, callbacks=[lr_schedule])
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 7/7 [==============================] - 5s 23ms/step - loss: 20.3698 - lr: 1.0000e-08
# Epoch 2/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3698 - lr: 1.1220e-08
# Epoch 3/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3698 - lr: 1.2589e-08
# Epoch 4/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3697 - lr: 1.4125e-08
# Epoch 5/100
# 7/7 [==============================] - 0s 23ms/step - loss: 20.3697 - lr: 1.5849e-08
# Epoch 6/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3697 - lr: 1.7783e-08
# Epoch 7/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3696 - lr: 1.9953e-08
# Epoch 8/100
# 7/7 [==============================] - 0s 24ms/step - loss: 20.3695 - lr: 2.2387e-08
# Epoch 9/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3695 - lr: 2.5119e-08
# Epoch 10/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3694 - lr: 2.8184e-08
# Epoch 11/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3693 - lr: 3.1623e-08
# Epoch 12/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3692 - lr: 3.5481e-08
# Epoch 13/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3691 - lr: 3.9811e-08
# Epoch 14/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3690 - lr: 4.4668e-08
# Epoch 15/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3689 - lr: 5.0119e-08
# Epoch 16/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3687 - lr: 5.6234e-08
# Epoch 17/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3685 - lr: 6.3096e-08
# Epoch 18/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3684 - lr: 7.0795e-08
# Epoch 19/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3682 - lr: 7.9433e-08
# Epoch 20/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3679 - lr: 8.9125e-08
# Epoch 21/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3677 - lr: 1.0000e-07
# Epoch 22/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3674 - lr: 1.1220e-07
# Epoch 23/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3670 - lr: 1.2589e-07
# Epoch 24/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3667 - lr: 1.4125e-07
# Epoch 25/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3663 - lr: 1.5849e-07
# Epoch 26/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3658 - lr: 1.7783e-07
# Epoch 27/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3653 - lr: 1.9953e-07
# Epoch 28/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3647 - lr: 2.2387e-07
# Epoch 29/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3640 - lr: 2.5119e-07
# Epoch 30/100
# 7/7 [==============================] - 0s 26ms/step - loss: 20.3633 - lr: 2.8184e-07
# Epoch 31/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3625 - lr: 3.1623e-07
# Epoch 32/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3615 - lr: 3.5481e-07
# Epoch 33/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3605 - lr: 3.9811e-07
# Epoch 34/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3593 - lr: 4.4668e-07
# Epoch 35/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3580 - lr: 5.0119e-07
# Epoch 36/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3566 - lr: 5.6234e-07
# Epoch 37/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3549 - lr: 6.3096e-07
# Epoch 38/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3531 - lr: 7.0795e-07
# Epoch 39/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3510 - lr: 7.9433e-07
# Epoch 40/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3487 - lr: 8.9125e-07
# Epoch 41/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3460 - lr: 1.0000e-06
# Epoch 42/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3431 - lr: 1.1220e-06
# Epoch 43/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3398 - lr: 1.2589e-06
# Epoch 44/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3361 - lr: 1.4125e-06
# Epoch 45/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3320 - lr: 1.5849e-06
# Epoch 46/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3274 - lr: 1.7783e-06
# Epoch 47/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3221 - lr: 1.9953e-06
# Epoch 48/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.3163 - lr: 2.2387e-06
# Epoch 49/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3097 - lr: 2.5119e-06
# Epoch 50/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.3024 - lr: 2.8184e-06
# Epoch 51/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.2941 - lr: 3.1623e-06
# Epoch 52/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.2849 - lr: 3.5481e-06
# Epoch 53/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.2745 - lr: 3.9811e-06
# Epoch 54/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.2628 - lr: 4.4668e-06
# Epoch 55/100
# 7/7 [==============================] - 0s 24ms/step - loss: 20.2498 - lr: 5.0119e-06
# Epoch 56/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.2351 - lr: 5.6234e-06
# Epoch 57/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.2186 - lr: 6.3096e-06
# Epoch 58/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.2002 - lr: 7.0795e-06
# Epoch 59/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.1794 - lr: 7.9433e-06
# Epoch 60/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.1562 - lr: 8.9125e-06
# Epoch 61/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.1301 - lr: 1.0000e-05
# Epoch 62/100
# 7/7 [==============================] - 0s 22ms/step - loss: 20.1008 - lr: 1.1220e-05
# Epoch 63/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.0680 - lr: 1.2589e-05
# Epoch 64/100
# 7/7 [==============================] - 0s 21ms/step - loss: 20.0311 - lr: 1.4125e-05
# Epoch 65/100
# 7/7 [==============================] - 0s 22ms/step - loss: 19.9898 - lr: 1.5849e-05
# Epoch 66/100
# 7/7 [==============================] - 0s 21ms/step - loss: 19.9434 - lr: 1.7783e-05
# Epoch 67/100
# 7/7 [==============================] - 0s 23ms/step - loss: 19.8913 - lr: 1.9953e-05
# Epoch 68/100
# 7/7 [==============================] - 0s 21ms/step - loss: 19.8329 - lr: 2.2387e-05
# Epoch 69/100
# 7/7 [==============================] - 0s 21ms/step - loss: 19.7674 - lr: 2.5119e-05
# Epoch 70/100
# 7/7 [==============================] - 0s 21ms/step - loss: 19.6939 - lr: 2.8184e-05
# Epoch 71/100
# 7/7 [==============================] - 0s 21ms/step - loss: 19.6114 - lr: 3.1623e-05
# Epoch 72/100
# 7/7 [==============================] - 0s 21ms/step - loss: 19.5188 - lr: 3.5481e-05
# Epoch 73/100
# 7/7 [==============================] - 0s 22ms/step - loss: 19.4150 - lr: 3.9811e-05
# Epoch 74/100
# 7/7 [==============================] - 0s 21ms/step - loss: 19.2985 - lr: 4.4668e-05
# Epoch 75/100
# 7/7 [==============================] - 0s 21ms/step - loss: 19.1677 - lr: 5.0119e-05
# Epoch 76/100
# 7/7 [==============================] - 0s 21ms/step - loss: 19.0210 - lr: 5.6234e-05
# Epoch 77/100
# 7/7 [==============================] - 0s 22ms/step - loss: 18.8565 - lr: 6.3096e-05
# Epoch 78/100
# 7/7 [==============================] - 0s 22ms/step - loss: 18.6718 - lr: 7.0795e-05
# Epoch 79/100
# 7/7 [==============================] - 0s 21ms/step - loss: 18.4646 - lr: 7.9433e-05
# Epoch 80/100
# 7/7 [==============================] - 0s 22ms/step - loss: 18.2321 - lr: 8.9125e-05
# Epoch 81/100
# 7/7 [==============================] - 0s 21ms/step - loss: 17.9713 - lr: 1.0000e-04
# Epoch 82/100
# 7/7 [==============================] - 0s 22ms/step - loss: 17.6787 - lr: 1.1220e-04
# Epoch 83/100
# 7/7 [==============================] - 0s 22ms/step - loss: 17.3503 - lr: 1.2589e-04
# Epoch 84/100
# 7/7 [==============================] - 0s 21ms/step - loss: 16.9819 - lr: 1.4125e-04
# Epoch 85/100
# 7/7 [==============================] - 0s 22ms/step - loss: 16.5685 - lr: 1.5849e-04
# Epoch 86/100
# 7/7 [==============================] - 0s 21ms/step - loss: 16.1047 - lr: 1.7783e-04
# Epoch 87/100
# 7/7 [==============================] - 0s 21ms/step - loss: 15.5843 - lr: 1.9953e-04
# Epoch 88/100
# 7/7 [==============================] - 0s 21ms/step - loss: 15.0004 - lr: 2.2387e-04
# Epoch 89/100
# 7/7 [==============================] - 0s 21ms/step - loss: 14.3453 - lr: 2.5119e-04
# Epoch 90/100
# 7/7 [==============================] - 0s 22ms/step - loss: 13.6102 - lr: 2.8184e-04
# Epoch 91/100
# 7/7 [==============================] - 0s 21ms/step - loss: 12.7855 - lr: 3.1623e-04
# Epoch 92/100
# 7/7 [==============================] - 0s 21ms/step - loss: 11.8601 - lr: 3.5481e-04
# Epoch 93/100
# 7/7 [==============================] - 0s 22ms/step - loss: 10.8218 - lr: 3.9811e-04
# Epoch 94/100
# 7/7 [==============================] - 0s 21ms/step - loss: 9.6569 - lr: 4.4668e-04
# Epoch 95/100
# 7/7 [==============================] - 0s 21ms/step - loss: 8.3498 - lr: 5.0119e-04
# Epoch 96/100
# 7/7 [==============================] - 0s 21ms/step - loss: 6.8832 - lr: 5.6234e-04
# Epoch 97/100
# 7/7 [==============================] - 0s 21ms/step - loss: 5.2380 - lr: 6.3096e-04
# Epoch 98/100
# 7/7 [==============================] - 0s 22ms/step - loss: 3.4918 - lr: 7.0795e-04
# Epoch 99/100
# 7/7 [==============================] - 0s 22ms/step - loss: 2.2909 - lr: 7.9433e-04
# Epoch 100/100
# 7/7 [==============================] - 0s 22ms/step - loss: 2.1310 - lr: 8.9125e-04

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(epochs) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-3, 0, 100])
# Out:
# (1e-08, 0.001, 0.0, 100.0)

# %%
tf.keras.backend.clear_session()
model.set_weights(init_weight)

# %%
# Set the learning rate
learning_rate = history.history['lr'][np.argmin(history.history['loss'])]

# Set callbacks
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('mae') < 0.1):
      print("\nMAE has reached 10%")
      self.model.stop_training = True

callbacks = myCallback()

# Set the optimizer
# optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
optimizer = tf.keras.optimizers.Adam(lr=learning_rate)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
history = model.fit(train_set, epochs=epochs, callbacks=[callbacks])
# Out:
# Epoch 1/100
# 7/7 [==============================] - 4s 31ms/step - loss: 27.5755 - mae: 28.0751
# Epoch 2/100
# 7/7 [==============================] - 0s 24ms/step - loss: 21.0044 - mae: 21.4991
# Epoch 3/100
# 7/7 [==============================] - 0s 22ms/step - loss: 9.4089 - mae: 9.8998
# Epoch 4/100
# 7/7 [==============================] - 0s 22ms/step - loss: 7.2912 - mae: 7.7713
# Epoch 5/100
# 7/7 [==============================] - 0s 22ms/step - loss: 4.3903 - mae: 4.8780
# Epoch 6/100
# 7/7 [==============================] - 0s 22ms/step - loss: 2.7864 - mae: 3.2611
# Epoch 7/100
# 7/7 [==============================] - 0s 21ms/step - loss: 2.2741 - mae: 2.7462
# Epoch 8/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.7175 - mae: 2.1675
# Epoch 9/100
# 7/7 [==============================] - 0s 24ms/step - loss: 1.9956 - mae: 2.4358
# Epoch 10/100
# 7/7 [==============================] - 0s 22ms/step - loss: 2.6830 - mae: 3.1763
# Epoch 11/100
# 7/7 [==============================] - 0s 23ms/step - loss: 2.3076 - mae: 2.7763
# Epoch 12/100
# 7/7 [==============================] - 0s 25ms/step - loss: 2.2466 - mae: 2.7367
# Epoch 13/100
# 7/7 [==============================] - 0s 21ms/step - loss: 1.8880 - mae: 2.3642
# Epoch 14/100
# 7/7 [==============================] - 0s 24ms/step - loss: 2.6244 - mae: 3.1026
# Epoch 15/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1.2533 - mae: 1.6868
# Epoch 16/100
# 7/7 [==============================] - 0s 25ms/step - loss: 1.3317 - mae: 1.7810
# Epoch 17/100
# 7/7 [==============================] - 0s 23ms/step - loss: 3.8054 - mae: 4.2874
# Epoch 18/100
# 7/7 [==============================] - 0s 22ms/step - loss: 3.1683 - mae: 3.6558
# Epoch 19/100
# 7/7 [==============================] - 0s 22ms/step - loss: 2.4927 - mae: 2.9601
# Epoch 20/100
# 7/7 [==============================] - 0s 23ms/step - loss: 4.2691 - mae: 4.7687
# Epoch 21/100
# 7/7 [==============================] - 0s 22ms/step - loss: 3.2797 - mae: 3.7689
# Epoch 22/100
# 7/7 [==============================] - 0s 22ms/step - loss: 3.4776 - mae: 3.9760
# Epoch 23/100
# 7/7 [==============================] - 0s 22ms/step - loss: 2.8585 - mae: 3.3451
# Epoch 24/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.1893 - mae: 1.6197
# Epoch 25/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.9053 - mae: 1.3250
# Epoch 26/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.2557 - mae: 1.7259
# Epoch 27/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.8493 - mae: 1.2866
# Epoch 28/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.8331 - mae: 1.2731
# Epoch 29/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.3675 - mae: 1.8557
# Epoch 30/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.9219 - mae: 2.3895
# Epoch 31/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.3451 - mae: 1.7962
# Epoch 32/100
# 7/7 [==============================] - 0s 21ms/step - loss: 1.1627 - mae: 1.6352
# Epoch 33/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.9065 - mae: 1.3418
# Epoch 34/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.9581 - mae: 1.3765
# Epoch 35/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.1405 - mae: 1.6210
# Epoch 36/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.1006 - mae: 1.5748
# Epoch 37/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.5851 - mae: 0.9832
# Epoch 38/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.3392 - mae: 0.6810
# Epoch 39/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.8071 - mae: 1.2401
# Epoch 40/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.0420 - mae: 1.5126
# Epoch 41/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1.8288 - mae: 2.2904
# Epoch 42/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4675 - mae: 0.8328
# Epoch 43/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.3403 - mae: 0.6693
# Epoch 44/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6247 - mae: 1.0033
# Epoch 45/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.5480 - mae: 0.9498
# Epoch 46/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.3391 - mae: 1.8238
# Epoch 47/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4941 - mae: 0.8660
# Epoch 48/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4910 - mae: 0.8759
# Epoch 49/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6148 - mae: 1.0137
# Epoch 50/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.2923 - mae: 1.7364
# Epoch 51/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4566 - mae: 0.8217
# Epoch 52/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7817 - mae: 1.1895
# Epoch 53/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.8047 - mae: 1.2140
# Epoch 54/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.3137 - mae: 1.7642
# Epoch 55/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.3722 - mae: 0.7195
# Epoch 56/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.8513 - mae: 1.2708
# Epoch 57/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.9171 - mae: 1.3824
# Epoch 58/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4389 - mae: 0.8107
# Epoch 59/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.2877 - mae: 0.5943
# Epoch 60/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.5485 - mae: 0.9262
# Epoch 61/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4234 - mae: 0.7939
# Epoch 62/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.3510 - mae: 0.6773
# Epoch 63/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.5483 - mae: 2.0025
# Epoch 64/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.8806 - mae: 1.3231
# Epoch 65/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.7859 - mae: 2.2646
# Epoch 66/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.9827 - mae: 1.4185
# Epoch 67/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.3905 - mae: 0.7166
# Epoch 68/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.2525 - mae: 0.5303
# Epoch 69/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.2696 - mae: 0.5791
# Epoch 70/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.2534 - mae: 0.5279
# Epoch 71/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.5108 - mae: 0.9172
# Epoch 72/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.9356 - mae: 1.3856
# Epoch 73/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.9254 - mae: 1.3893
# Epoch 74/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7932 - mae: 1.2482
# Epoch 75/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7578 - mae: 1.1928
# Epoch 76/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6732 - mae: 1.0673
# Epoch 77/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.8308 - mae: 1.2764
# Epoch 78/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.4757 - mae: 0.8628
# Epoch 79/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.8207 - mae: 1.2652
# Epoch 80/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.7615 - mae: 1.1932
# Epoch 81/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.5358 - mae: 0.9132
# Epoch 82/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6870 - mae: 1.1175
# Epoch 83/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.6869 - mae: 1.1191
# Epoch 84/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.1577 - mae: 1.6129
# Epoch 85/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1.7637 - mae: 2.2408
# Epoch 86/100
# 7/7 [==============================] - 0s 22ms/step - loss: 1.7232 - mae: 2.2193
# Epoch 87/100
# 7/7 [==============================] - 0s 24ms/step - loss: 1.6463 - mae: 2.1433
# Epoch 88/100
# 7/7 [==============================] - 0s 25ms/step - loss: 2.3030 - mae: 2.7887
# Epoch 89/100
# 7/7 [==============================] - 0s 21ms/step - loss: 1.1282 - mae: 1.5783
# Epoch 90/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.7060 - mae: 1.1017
# Epoch 91/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.4957 - mae: 0.8648
# Epoch 92/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.7740 - mae: 1.2028
# Epoch 93/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.4528 - mae: 0.8210
# Epoch 94/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.3590 - mae: 0.7026
# Epoch 95/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.2934 - mae: 0.6060
# Epoch 96/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.2944 - mae: 0.5971
# Epoch 97/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.6142 - mae: 1.0140
# Epoch 98/100
# 7/7 [==============================] - 0s 23ms/step - loss: 1.0188 - mae: 1.4829
# Epoch 99/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.3743 - mae: 0.7203
# Epoch 100/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.3228 - mae: 0.6485

# %%
# Get mae and loss from history log
mae=history.history['mae']
loss=history.history['loss']

# Get number of epochs
epochs=range(len(loss))

# Plot mae and loss
plot_series(
    x=epochs,
    y=(mae, loss),
    title='MAE and Loss',
    xlabel='MAE',
    ylabel='Loss',
    legend=['MAE', 'Loss']
    )

# Only plot the last 80% of the epochs
zoom_split = int(epochs[-1] * 0.2)
epochs_zoom = epochs[zoom_split:]
mae_zoom = mae[zoom_split:]
loss_zoom = loss[zoom_split:]

# Plot zoomed mae and loss
plot_series(
    x=epochs_zoom,
    y=(mae_zoom, loss_zoom),
    title='MAE and Loss',
    xlabel='MAE',
    ylabel='Loss',
    legend=['MAE', 'Loss']
    )

# %% [markdown]
# # Model Prediction

# %%
def model_forecast(model, series, window_size, batch_size):
  """
  Forecasts the time series using the model

  Args:
    model - the model to use for forecasting
    series (array of int) - the time series
    window_size (int) - the window size

  Returns:
    forecast - the forecasted values
  """

  # Create a dataset from the series
  dataset = tf.data.Dataset.from_tensor_slices(series)

  # Window the dataset
  dataset = dataset.window(window_size, shift=1, drop_remainder=True)

  # Flatten the dataset
  dataset = dataset.flat_map(lambda window: window.batch(window_size))

  # Batch the dataset
  dataset = dataset.batch(32).prefetch(1)

  # Forecast the values
  forecast = model.predict(dataset)

  return forecast

# %%
# Reduce the original series
forecast_series = series[split_time-window_size:-1]

# Use helper function to generate predictions
forecast = model_forecast(model, forecast_series, window_size, batch_size)

# Drop single dimensional axis
results = forecast.squeeze()

# Plot the results and show actual values vs predicted values
plot_series(time_valid, (x_valid, results), xlabel="Time", ylabel="Inflation Rate", legend=["Actual", "Forecast"])
# Out:
# 1/1 [==============================] - 1s 763ms/step

# %%
# Compute the MAE
print(tf.keras.metrics.mean_absolute_error(x_valid, results).numpy())
# Out:
# 0.8042698

# %%
def months_to_reach_goal(goal_nominal, monthly_income, monthly_expenses):
    # Assuming a constant inflation rate
    inflation_rate = 0.02  # Adjust this value according to your prediction model

    # Calculate the monthly savings
    monthly_savings = monthly_income - monthly_expenses

    # Initialize the total savings and the number of months
    total_savings = 0
    months = 0

    # Loop until the total savings reach the goal nominal
    while total_savings < goal_nominal:
        # Add the monthly savings to the total savings
        total_savings += monthly_savings

        # Adjust the total savings for inflation
        total_savings *= (1 - inflation_rate)

        # Increment the number of months
        months += 1

    return months

# %%
# export model
model.save('model.h5')
